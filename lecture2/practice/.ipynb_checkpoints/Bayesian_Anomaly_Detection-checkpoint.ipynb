# %% [markdown]
# # Setup

# %%
import stan
import pandas as pd
import numpy as np
import scipy.stats as stats 
import matplotlib
import arviz as az
import matplotlib.pyplot as plt
#matplotlib.rcParams['figure.figsize']=5,5
matplotlib.rcParams['figure.dpi']=100
#plt.style.use('ggplot')
from IPython.display import Image

# %%
# this is a work around found at 
# https://stackoverflow.com/questions/56154176/runtimeerror-asyncio-run-cannot-be-called-from-a-running-event-loop-in-spyd
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# # Let's play

# %%
data = pd.read_csv('Consultas.csv', index_col=0)
data[-3:]
# Out:
#          Fecha  Clinica #0  Clinica #1  Clinica #2  Clinica #3  Clinica #4  \
# 37  2024-09-11        42.0        41.0        92.0        46.0        59.0
# 38  2024-09-12        23.0        54.0        68.0        19.0        40.0
# 39  2024-09-13        25.0        37.0        59.0        15.0        39.0
#
#     Clinica #5  Clinica #6  Clinica #7  Clinica #8  ...  Clinica #48  \
# 37        52.0        31.0         6.0        33.0  ...         36.0
# 38        46.0        14.0         3.0        48.0  ...         36.0
# 39        20.0        17.0         8.0        31.0  ...         27.0
#
#     Clinica #49  Clinica #50  Clinica #51  Clinica #52  Clinica #53  \
# 37        213.0         36.0         15.0         12.0         32.0
# 38        247.0         46.0         14.0         13.0         31.0
# 39        161.0         35.0         16.0         18.0         12.0
#
#     Clinica #54  Clinica #55  Clinica #56  Clinica #57
# ...

# %%
# We verify the hypothesis: there is an approximate ratio in practices for all clinics
plt.plot(data[list(data)[1]], label='Clinic i')
plt.plot(data[list(data)[12]], label='Clinic j')
plt.plot(data[list(data)[7]], label='Clinic k')
plt.plot(data[list(data)[19]], label='Clinic l')
plt.plot(data[list(data)[15]], label='Clinic m')
plt.xlabel('Days')
plt.ylabel('Medical Practices')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# It is an approximation and it is supposed to have an uncertainty

# %% [markdown]
# ## Bayesian modeling with STAN
#
# Modelamos que la cantidad de consultas que hace la clínica $n$ el día $t$ es sampleado de una Poisson cuyo rate es el producto del tamaño de la clínica $s_n$ por un indicador de la magnitud del día, $d_t$: consultas ~ Poissson($s_n\, d_t$).

# %%
Image("graphical_model.png")

# %%
# definimos el modelo Bayesiano para ejecutar con STAN
# (Observar que no es de la clase de modelos que tiene Likelihood, simplemente el modelo es igualar los datos a una función de los parámetros)
my_model="""
data {
 int <lower=0> N; // number of clinics
 int <lower=0> T; // number of days in the dataset
 int <lower=0> my_max; // max # of practices in the dataset to break degeneracies
 array[T,N] int<lower=0> practices;  // practices on day t in clinic n: practices[t,n]
 
}

parameters {
  vector<lower=0, upper=1>[T] d; // parameter that measures how 'hot' is each day
  vector<lower=0, upper=my_max>[N] s; // parameter that estimates the size of each clinic
  real <lower=0> eps;
}

model {

   for (n in 1:N) {
       for (t in 1:T) {
           eps ~ normal(0, d[t]*s[n]/10 ); // A clinic can be randomly smaller because some missing doctors
           practices[t,n] ~ poisson( d[t]*s[n] - eps );
     }; 
     };
}
"""

# %%
int(data[list(data)[1:]].max().max())
# Out:
# 1470

# %%
# Definimos el diccionario que contiene la data que necesita el modelo
# Observar que my_max es la cantidad máxima diaria de consultas del dataset.  El modelo lo hicimos de modo que s*d en ese 
# caso requiera que d = 1, ya que s se samplea hasta my_max.  Esto es necesario para que no haya degeneración.  Si no 
# habría diversas soluciones todas igual de válidas, ya que uno puede bajar d y aumentar s, y sigue siendo todo igual de válido
# Parecería ser que funcionó este truco
my_data = {'N': len(list(data)), 'T':len(data), 'my_max': int(data[list(data)[1:]].max().max()), 'consultas': np.array(data[list(data)[1:]]).astype(int) }

# %%
# Metemos la data al modelo para construir el modelo
model = stan.build(my_model, data=my_data, random_seed=1);
# Out:
# Building: 0.1s
# Building: 0.2s
# Building: 0.3s
# Building: 0.4s
# Building: 0.5s
# Building: 0.6s
# Building: 0.7s
# Building: 0.8s
# Building: 0.9s
# Building: 1.0s
# Building: 1.1s
# Building: 1.2s
# Building: 1.3s
# Building: 1.4s
# Building: 1.5s
# Building: 1.6s
# Building: 1.7s
# Building: 1.8s
# Building: 1.9s
# Building: 2.0s
# Building: 2.1s
# Building: 2.2s
# Building: 2.3s
# Building: 2.4s
# Building: 2.5s
# Building: 2.7s
# Building: 2.8s
# Building: 2.9s
# Building: 3.0s
# Building: 3.1s
# Building: 3.2s
# Building: 3.3s
# Building: 3.4s
# Building: 3.5s
# Building: 3.6s
# Building: 3.7s
# Building: 3.8s
# Building: 3.9s
# Building: 4.0s
# Building: 4.1s
# Building: 4.2s
# Building: 4.3s
# Building: 4.4s
# Building: 4.5s
# Building: 4.6s
# Building: 4.7s
# Building: 4.8s
# Building: 4.9s
# Building: 5.0s
# Building: 5.1s
# Building: 5.2s
# Building: 5.3s
# Building: 5.4s
# Building: 5.5s
# Building: 5.6s
# Building: 5.7s
# Building: 5.8s
# Building: 5.9s
# ...

# %%
# Lo fiteamos.  
# o sea, sampleamos de la posterior para toas las variables del modelo
fit = model.sample(num_chains=4, num_samples=1000, delta=080)

# %%
# Construimos el dataframe de la posterior ya que es lo que necesitamos para hacer nuestro trabajo
df = fit.to_frame() 
df

# %%
# Verificamos que el parámetro rhat < 1.05, lo que nos da la certeza de que el sampleo está en equilibrio e insesgado
azdata = az.from_pystan(fit)
summary = az.summary(azdata)
summary
# Out:
#            mean      sd    hdi_3%   hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# d[0]      0.795   0.021     0.760     0.837      0.002    0.001     151.0
# d[1]      0.815   0.022     0.780     0.860      0.002    0.001     148.0
# d[2]      0.665   0.018     0.633     0.699      0.001    0.001     156.0
# d[3]      0.139   0.006     0.128     0.150      0.000    0.000     358.0
# d[4]      0.067   0.004     0.060     0.074      0.000    0.000     592.0
# ...         ...     ...       ...       ...        ...      ...       ...
# s[42]    31.022   1.495    28.356    33.927      0.066    0.047     512.0
# s[43]   288.058   7.360   274.131   301.234      0.637    0.451     141.0
# s[44]   499.603  12.196   475.585   519.602      1.116    0.791     128.0
# s[45]  1428.244  30.550  1373.566  1469.989      3.103    2.201     114.0
# eps       0.005   0.005     0.000     0.013      0.000    0.000    2961.0
#
#        ess_tail  r_hat
# d[0]      273.0   1.04
# d[1]      336.0   1.04
# ...

# %% [markdown]
# The rhat should be below to 1.01 (1.05 acceptable) to have a fully confident sampling.  It is "ok"

# %%
plt.hist(summary['r_hat'])
plt.show()

# %% [markdown]
# ### Let's sort the clinics
#
# We sort them from most unlikely because being above the expectation, to the most unlikey for being below the expectation.  All this corresponds to the given day of study.
#
# We can start by computing the average p-value
# $$\langle p_n \rangle = \langle \sum_{x=consultas[n]@d_0}^\infty PoissonPDF(x; d_0 \cdot s[n]) \rangle $$
# for every clinic $n$, where $d_0$  is the day of study.  The clinic that has the minimum $\langle p_n \rangle$ is the most unlikely from above, that we're looking for.

# %%
# Dataframe with all the required info to compute <p_n>
my_day = df[['d.'+str(len(data3))]+['s.'+str(i+1) for i in range(len(list(data3)))]]
my_day[:4]
# Out:
# parameters      d.30        s.1        s.2         s.3        s.4        s.5  \
# draws
# 0           0.633474  37.087605  50.798455   95.422985  43.859970  39.633358
# 1           0.628764  39.142919  52.017451   98.842144  41.588922  41.009206
# 2           0.604118  39.729583  54.764798  105.566420  46.595544  41.029085
# 3           0.617298  37.769365  56.482792  102.662803  40.974978  40.812289
#
# parameters        s.6        s.7        s.8        s.9  ...        s.37  \
# draws                                                   ...
# 0           39.858669  26.763810  27.164690  39.011917  ...  103.073645
# 1           42.322318  25.159895  28.044233  43.551138  ...  104.837993
# 2           42.085505  27.196496  31.538685  41.846742  ...  106.051952
# 3           40.157741  25.648103  26.412234  39.144663  ...  106.545348
#
# parameters        s.38       s.39       s.40        s.41       s.42  \
# draws
# 0           663.682807  20.387139  45.465431  254.370986  53.853069
# ...

# %%
clinics = list(data3)
probabilities = pd.DataFrame()
for i in range(len(clinics)):
    if i % 10 ==0: print(i,'/',len(clinics))
    tmp = []
    for k in range(len(my_day)):
    #for k in range(10):
        #k = np.random.randint(0,len(lastday))
        # Here I compute a sum to infinity using the CDF of the Poisson distribution
        tmp.append( 1 - stats.poisson.cdf(data3.iloc[-1][clinics[i]], my_day.iloc[k]['d.'+str(len(data3))] * my_day.iloc[k]['s.'+str(i+1)]))
    probabilities[clinics[i]] = [np.mean(tmp), np.std(tmp),int(data3.iloc[-1][clinics[i]]), np.mean(my_day['d.'+str(len(data3))]) * np.mean(my_day['s.'+str(i+1)]), [my_day.iloc[k]['d.'+str(len(data3))] * my_day.iloc[k]['s.'+str(i+1)] for k in range(len(my_day))]]
probabilities.index = ['<p_n>','SD(p_n)','consultas_my_day','Poisson_mean_rate', 'rate_list']
# Out:
# 0 / 46
# 10 / 46
# 20 / 46
# 30 / 46
# 40 / 46

# %%
# This new dataframe has all the info!
# Lo ordenamos de menor a mayor en <p_n>, de modo que la primer clínica es aquella que 
# tuvo consultas más por arriba de lo esperado
probabilities.sort_values(by = '<p_n>', axis = 1, inplace=True) 
probabilities
# Out:
#                                             SANATORIO SINDICAL SUOEM  \
# <p_n>                                                       0.000001
# SD(p_n)                                                     0.000003
# consultas_my_day                                                 246
# Poisson_mean_rate                                         176.840585
# rate_list          [174.52429195202322, 179.79876471972236, 178.8...
#
#                                  CLINICA DE OJOS MALDONADO BAS PRIVA  \
# <p_n>                                                       0.005031
# SD(p_n)                                                      0.00337
# consultas_my_day                                                  26
# Poisson_mean_rate                                          15.300263
# rate_list          [14.046447400410713, 15.295326252098725, 15.21...
#
#                                                            CEMO S.A.  \
# ...

# %% [markdown]
# ## Resultado!
#
# Este es el resultado.  El $\langle p_n \rangle$ nos dice cuán unlikely por arriba es el número de consultas reportadas
#
# Grafiquemos las primeras y últimas de este dataframe.

# %%
for name in list(probabilities)[:2]: 
    plt.plot(np.array(data0['Fecha'][:]), np.array(data0[name][:]),marker='o')
    plt.plot(np.array(data0['Fecha'])[-1], np.array(data0[name])[-1],marker='o',color='magenta', label='Tested point\nvs expected')
    #plt.scatter(np.array(data['Fecha'])[-day_of_study-1], np.array(data[name])[-day_of_study-1],marker='o',color='magenta', label='Tested point')
    plt.axvspan(np.array(data0['Fecha'])[start_not_learning_block],np.array(data0['Fecha'])[end_not_learning_block], alpha=0.3, color='red', label='Not used for learning')
    for i in range(len(probabilities.iloc[4][name])):
    #for i in range(10):
        tmp = stats.poisson.rvs(probabilities.iloc[4][name][i], size=3)
        for j in range(len(tmp)):
            plt.axhline(tmp[j], alpha=0.003, linestyle='solid', linewidth=4,  color='magenta')
        #plt.axhline(probabilities.iloc[4][name][i], alpha=0.003, linestyle='solid', color='red')
    plt.xticks(rotation=70, fontsize=9)
    plt.ylabel('# practices')
    plt.title(name)
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

# %%
for name in list(probabilities)[-2:]: 
    plt.plot(np.array(data0['Fecha'][:]), np.array(data0[name][:]),marker='o')
    plt.plot(np.array(data0['Fecha'])[-1], np.array(data0[name])[-1],marker='o',color='magenta', label='Tested point\nvs expected')
    #plt.scatter(np.array(data['Fecha'])[-day_of_study-1], np.array(data[name])[-day_of_study-1],marker='o',color='magenta', label='Tested point')
    plt.axvspan(np.array(data0['Fecha'])[start_not_learning_block],np.array(data0['Fecha'])[end_not_learning_block], alpha=0.3, color='red', label='Not used for learning')
    for i in range(len(probabilities.iloc[4][name])):
    #for i in range(10):
        tmp = stats.poisson.rvs(probabilities.iloc[4][name][i], size=3)
        for j in range(len(tmp)):
            plt.axhline(tmp[j], alpha=0.003, linestyle='solid', linewidth=4,  color='magenta')
        #plt.axhline(probabilities.iloc[4][name][i], alpha=0.003, linestyle='solid', color='red')
    plt.xticks(rotation=70, fontsize=9)
    plt.ylabel('# of practices')
    plt.title(name)
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()
